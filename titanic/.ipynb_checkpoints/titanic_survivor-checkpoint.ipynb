# %% [markdown]
# # Titanic: Machine Learning from Disaster #

# %% [markdown]
# - Exploratory Data Analysis (EDA) with Visualization
# - Feature Extraction
# - Data Modelling
# - Model Evaluation

# %% [markdown]
# ## Overview ##
#
# The data has been split into two groups:
#
# - training set (train.csv)
# - test set (test.csv)
#
# The **training** set should be used to build your machine learning models. For the training set, we provide the outcome (also known as the “ground truth”) for each passenger. Your model will be based on “features” like passengers’ gender and class. You can also use feature engineering to create new features.
#
# The **test** set should be used to see how well your model performs on unseen data. For the test set, we do not provide the ground truth for each passenger. It is your job to predict these outcomes. For each passenger in the test set, use the model you trained to predict whether or not they survived the sinking of the Titanic.
#
# We also include **gender_submission.csv**, a set of predictions that assume all and only female passengers survive, as an example of what a submission file should look like.

# %% [markdown]
# ## Variable Notes ##
#
# **pclass:** A proxy for socio-economic status (SES)
# 1st = Upper
# 2nd = Middle
# 3rd = Lower
#
# **age:** Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5
#
# **sibsp:** The dataset defines family relations in this way...
# Sibling = brother, sister, stepbrother, stepsister
# Spouse = husband, wife (mistresses and fiancés were ignored)
#
# **parch:** The dataset defines family relations in this way...
# Parent = mother, father
# Child = daughter, son, stepdaughter, stepson
# Some children travelled only with a nanny, therefore parch=0 for them.

# %%
import os
import sys
import pickle
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns


pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth',1000)

# %%
#To check if libraries are installed or not

'numpy' in sys.modules
# Out:
# True

# %%
print(os.getcwd())
print(os.listdir(os.getcwd()))
# Out:
# C:\Users\tshrs\Documents\Udacity\projects\titanic
# ['.ipynb_checkpoints', 'gender_submission.csv', 'test.csv', 'titanic_survivor.ipynb', 'train.csv']

# %%
test_data = pd.read_csv("test.csv")
train_data = pd.read_csv("train.csv")

# %% [markdown]
#
# # 1- EDA with Visualization
# ----------------------------------------------

# %%
test_data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# ### Data Dictionary ##
#
# | Variable 	| Definition                                 	| Key                                            	|
# |----------	|--------------------------------------------	|------------------------------------------------	|
# | survival 	| Survival                                   	| 0 = No, 1 = Yes                                	|
# | pclass   	| Ticket class                               	| 1 = 1st, 2 = 2nd, 3 = 3rd                      	|
# | sex      	| Sex                                        	|                                                	|
# | Age      	| Age in years                               	|                                                	|
# | sibsp    	| # of siblings / spouses aboard the Titanic 	|                                                	|
# | parch    	| # of parents / children aboard the Titanic 	|                                                	|
# | ticket   	| Ticket number                              	|                                                	|
# | fare     	| Passenger fare                             	|                                                	|
# | cabin    	| Cabin number                               	|                                                	|
# | embarked 	| Port of Embarkation                        	| C = Cherbourg, Q = Queenstown, S = Southampton 	|

# %% [markdown]
# The above table is created using the link https://www.tablesgenerator.com/markdown_tables#

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
test_data.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
train_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#no. of rows=records and column=features
print(test_data.shape)
print(train_data.shape)
# Out:
# (418, 11)
# (891, 12)

# %%
### Summary statistics of character(O=object) column

train_data.describe(include=['O'])
# Out:
#                              Name   Sex Ticket Cabin Embarked
# count                         891   891    891   204      889
# unique                        891     2    681   147        3
# top     Sjoblom, Miss. Anna Sofia  male   1601    G6        S
# freq                            1   577      7     4      644

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# ## Realtion between features and survival(outcome or predicted class) ##

# %%
survived = train_data[train_data['Survived'] == 1]
not_survived = train_data[train_data['Survived'] == 0]

print("Survived : ", len(survived))
print("Not Survived : ", len(not_survived))

print ("Total passengers in training data set : ", len(survived) + len((not_survived)))
# Out:
# Survived :  342
# Not Survived :  549
# Total passengers in training data set :  891

# %% [markdown]
# ### Pclass vs Survived ###

# %%
train_data['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
train_data.groupby(['Pclass','Survived'])['Survived'].count()
# Out:
# Pclass  Survived
# 1       0            80
#         1           136
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: Survived, dtype: int64

# %%
### data frame with 2 columns pclass ad survived, calculating the mean on plcass excluding nan. 
### as_index will keep the index of the returned object

train_data[['Pclass', 'Survived']].groupby(['Pclass'], as_index=False).mean()
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %% [markdown]
# **The survival rate is highest for Pclass = 1 passengers**

# %%
ax = sns.countplot(x="Pclass", hue="Survived", data=train_data)

# %% [markdown]
# ### Sex vs Survived ###

# %%
train_data['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
train_data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
train_data[['Sex', 'Survived']].groupby(['Sex'], as_index=False).mean()
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %% [markdown]
# **Female survival rate is highest.**

# %%
sns.set(style="whitegrid")

ax = sns.countplot(x="Sex", hue="Survived", data=train_data)

# %% [markdown]
# ### Pclass and Sex vs Survival ###

# %%
### understand cross table from here
### http://pbpython.com/pandas-crosstab.html
    
train_data_cross = pd.crosstab( train_data['Pclass'], train_data['Sex'] , margins=True , margins_name = "Total" )
train_data_cross
# Out:
# Sex     female  male  Total
# Pclass
# 1           94   122    216
# 2           76   108    184
# 3          144   347    491
# Total      314   577    891

# %% [markdown]
# **Male passengers are the most in Pclass=3**

# %%
train_data.groupby(['Sex','Pclass','Survived'])['Survived'].count()
# Out:
# Sex     Pclass  Survived
# female  1       0             3
#                 1            91
#         2       0             6
#                 1            70
#         3       0            72
#                 1            72
# male    1       0            77
#                 1            45
#         2       0            91
#                 1            17
#         3       0           300
#                 1            47
# Name: Survived, dtype: int64

# %%
### for better explanation of factorplot, see here
### https://blog.insightdatascience.com/data-visualization-in-python-advanced-functionality-in-seaborn-20d217f1a9a6
    

sns.factorplot(data = train_data , x = 'Sex' , y= 'Survived' , hue= 'Pclass')

# %% [markdown]
# **From above analysis we can say that:**
#
# - Females in class 1 and 2 have almost 100% chance of surviving
# - Males in class 2 and 3 have almost no chance of surviving

# %% [markdown]
#
# ### Pclass, Sex and Embarked vs Survival###

# %%
sns.factorplot(data = train_data , x = 'Pclass' , y= 'Survived' , col='Embarked' , hue= 'Sex')

# %% [markdown]
# **Females**
#
# - class 1 and 2 females embarked from all 3 ports survival looks almost 100%
# - class 3 females around 50% on an average
#
# **Males**
#
# - Males embarked from Southampton and Cherbourg survival rate is around 20-40% for all classes
# - Males embarked from Queenstown(Q) survival rate is almost 0 for all the classes.

# %% [markdown]
# ### Survived vs Embarked ##

# %%
train_data['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
train_data.groupby(['Embarked','Survived'])['Survived'].count()
# Out:
# Embarked  Survived
# C         0            75
#           1            93
# Q         0            47
#           1            30
# S         0           427
#           1           217
# Name: Survived, dtype: int64

# %%
train_data[['Embarked', 'Survived']].groupby(['Embarked'], as_index=False).mean()
# Out:
#   Embarked  Survived
# 0        C  0.553571
# 1        Q  0.389610
# 2        S  0.336957

# %%
ax = sns.countplot(x="Embarked", hue="Survived", data=train_data)

# %% [markdown]
# -  Survival rate for Cherbourg is highest, but for Southampton the survival rate is almost 30%

# %% [markdown]
# ### Survived vs parch

# %%
train_data['Parch'].value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %% [markdown]
# ***The above means no parents or zero children***

# %%
train_data.groupby(['Parch','Survived'])['Survived'].count()
# Out:
# Parch  Survived
# 0      0           445
#        1           233
# 1      0            53
#        1            65
# 2      0            40
#        1            40
# 3      0             2
#        1             3
# 4      0             4
# 5      0             4
#        1             1
# 6      0             1
# Name: Survived, dtype: int64

# %%
train_data[['Parch', 'Survived']].groupby(['Parch'], as_index=False).mean()
# Out:
#    Parch  Survived
# 0      0  0.343658
# 1      1  0.550847
# 2      2  0.500000
# 3      3  0.600000
# 4      4  0.000000
# 5      5  0.200000
# 6      6  0.000000

# %%
ax = sns.countplot(x="Parch", hue="Survived", data=train_data)

# %% [markdown]
# ### Survival vs SibSp

# %%
train_data['SibSp'].value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
train_data[['SibSp', 'Survived']].groupby(['SibSp'], as_index=False).mean()
# Out:
#    SibSp  Survived
# 0      0  0.345395
# 1      1  0.535885
# 2      2  0.464286
# 3      3  0.250000
# 4      4  0.166667
# 5      5  0.000000
# 6      8  0.000000

# %% [markdown]
# ### Parch, SibSp & Sex vs Survived

# %%
sns.factorplot(data = train_data , x = 'Parch' , y= 'Survived' , col= 'Sex')

# %%
sns.factorplot(data = train_data , x = 'SibSp' , y= 'Survived' , col= 'Sex')

# %% [markdown]
# ***The Parch and Sibsp features shows that***
#
# - *people with 0 count has less survival chance, out of those -- females survival rate is almost 80%, probably because men were not allowed to board the rescue ship*
# - *people with count of 1 and 2 have almost 50% survival rate, out of those -- females survival rate goes up to 80% again, also children lie in this category hence the total survival rate goes up.*

# %% [markdown]
# ### Age vs Survival
#
# ***Here age has lot of values so we cannot use bar or factorplot charts, we need a chart which shows distribution***

# %%
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(131)
ax2 = fig.add_subplot(132)
ax3 = fig.add_subplot(133)

sns.violinplot(x="Embarked", y="Age", hue="Survived", data=train_data, split=True, ax=ax1)
sns.violinplot(x="Pclass", y="Age", hue="Survived", data=train_data, split=True, ax=ax2)
sns.violinplot(x="Sex", y="Age", hue="Survived", data=train_data, split=True, ax=ax3)

# %% [markdown]
# **The above graph tells us:**
#
# *For Pclass*
#
# - Class=1
#     - There are almost no children and mostly adults with median age(interquartile range) of around 38 years.
#     - The survival rate of adults is lesser i.e. mostly people above 50.
#
# - Class=2 and 3
#    - There are mostly children in these 2 classes and the survival rate is much higher(100% for class=2) for children from 0-15.
#
# *For Sex*
#
# - Male survival rate for age between 0-18 is higher as compared to females in the similar age.
# - Females of all the ages have better survival rate then men

# %%
# Compute the correlation matrix
corr = train_data.drop('PassengerId',axis=1).corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Generate a custom diverging colormap
#cmap = sns.diverging_palette(220, 10, as_cmap=True)

plt.figure(figsize=(15,6))
sns.heatmap(corr,  vmax=0.6,   annot=True, square=True)

# %% [markdown]
# # 2- Feature Extraction
# ------------------------------------

# %%
type(train_data)
# Out:
# pandas.core.frame.DataFrame

# %%
type(test_data)
# Out:
# pandas.core.frame.DataFrame

# %%
# Merging the train and test data set


train_test_list = [ train_data, test_data ]

#here ignore_index True will create new values from 0 to n-1
train_test_data = pd.concat(train_test_list, ignore_index=True)


train_test_data.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                   Name  Parch  PassengerId  \
# 0                              Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)      0            2
# 2                               Heikkinen, Miss. Laina      0            3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                             Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket
# 0       3    male      1       0.0         A/5 21171
# 1       1  female      1       1.0          PC 17599
# 2       3  female      0       1.0  STON/O2. 3101282
# 3       1  female      1       1.0            113803
# ...

# %% [markdown]
# ***By using the code train_test_data = pd.concat([test_data,train_data])
# the indexes were duplicated, this we got to know at a very later stage, when checking for the max and min value of fare which
# returned 2 rows with same index.***
#
# **Below code gives the count of duplicate indexes -- remove len and you can see all rows**
#
# *len(train_test_data[train_test_data.index.duplicated(keep=False)]*
#
# **Below code gives the count if count if single duplicate**
#
# *len(train_test_data[train_test_data.index.duplicated()])*

# %%
train_test_data.describe()
# Out:
#                Age         Fare        Parch  PassengerId       Pclass  \
# count  1046.000000  1308.000000  1309.000000  1309.000000  1309.000000
# mean     29.881138    33.295479     0.385027   655.000000     2.294882
# std      14.413493    51.758668     0.865560   378.020061     0.837836
# min       0.170000     0.000000     0.000000     1.000000     1.000000
# 25%      21.000000     7.895800     0.000000   328.000000     2.000000
# 50%      28.000000    14.454200     0.000000   655.000000     3.000000
# 75%      39.000000    31.275000     0.000000   982.000000     3.000000
# max      80.000000   512.329200     9.000000  1309.000000     3.000000
#
#              SibSp    Survived
# count  1309.000000  891.000000
# mean      0.498854    0.383838
# std       1.041658    0.486592
# min       0.000000    0.000000
# 25%       0.000000    0.000000
# 50%       0.000000    0.000000
# 75%       1.000000    1.000000
# max       8.000000    1.000000

# %%
# Null values 

train_test_data.isnull().sum()
# Out:
# Age             263
# Cabin          1014
# Embarked          2
# Fare              1
# Name              0
# Parch             0
# PassengerId       0
# Pclass            0
# Sex               0
# SibSp             0
# Survived        418
# Ticket            0
# dtype: int64

# %% [markdown]
# If we combine the train and test data below are the missing values:
#
# - Age is missing for 263 people
# - Cabin is missing for 1014
# - Embarked is missing for 2 rows

# %% [markdown]
# ### Name feature

# %%
### Extracting the title from the Name feature -- will give us the details whether child, spouse, husband, male, female etc.

#for dataset in train_test_data:

train_test_data['Title' ] = train_test_data['Name'].str.extract("([A-Za-z]+)\.",expand=True) 

train_test_data.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                   Name  Parch  PassengerId  \
# 0                              Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)      0            2
# 2                               Heikkinen, Miss. Laina      0            3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                             Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket Title
# 0       3    male      1       0.0         A/5 21171    Mr
# 1       1  female      1       1.0          PC 17599   Mrs
# 2       3  female      0       1.0  STON/O2. 3101282  Miss
# 3       1  female      1       1.0            113803   Mrs
# ...

# %%
train_test_data['Title'].value_counts()
# Out:
# Mr          757
# Miss        260
# Mrs         197
# Master       61
# Dr            8
# Rev           8
# Col           4
# Ms            2
# Major         2
# Mlle          2
# Lady          1
# Jonkheer      1
# Capt          1
# Mme           1
# Countess      1
# Dona          1
# Don           1
# Sir           1
# Name: Title, dtype: int64

# %%
train_test_data[['Title', 'Survived']].groupby(['Title'], as_index=False).mean()

##as_index= False will not make Title(mentioned in groupby clause as index)
# Out:
#        Title  Survived
# 0       Capt  0.000000
# 1        Col  0.500000
# 2   Countess  1.000000
# 3        Don  0.000000
# 4       Dona       NaN
# 5         Dr  0.428571
# 6   Jonkheer  0.000000
# 7       Lady  1.000000
# 8      Major  0.500000
# 9     Master  0.575000
# 10      Miss  0.697802
# 11      Mlle  1.000000
# 12       Mme  1.000000
# 13        Mr  0.156673
# 14       Mrs  0.792000
# 15        Ms  1.000000
# 16       Rev  0.000000
# 17       Sir  1.000000

# %%
pd.crosstab( train_test_data['Title'], train_test_data['Sex'] , margins=True , margins_name = "Total" )
# Out:
# Sex       female  male  Total
# Title
# Capt           0     1      1
# Col            0     4      4
# Countess       1     0      1
# Don            0     1      1
# Dona           1     0      1
# Dr             1     7      8
# Jonkheer       0     1      1
# Lady           1     0      1
# Major          0     2      2
# Master         0    61     61
# Miss         260     0    260
# Mlle           2     0      2
# Mme            1     0      1
# Mr             0   757    757
# Mrs          197     0    197
# Ms             2     0      2
# Rev            0     8      8
# Sir            0     1      1
# Total        466   843   1309

# %% [markdown]
#
# There are some titles which are meaningful, we replace those title with "Others"

# %%
train_test_data.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                   Name  Parch  PassengerId  \
# 0                              Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)      0            2
# 2                               Heikkinen, Miss. Laina      0            3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                             Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket Title
# 0       3    male      1       0.0         A/5 21171    Mr
# 1       1  female      1       1.0          PC 17599   Mrs
# 2       3  female      0       1.0  STON/O2. 3101282  Miss
# 3       1  female      1       1.0            113803   Mrs
# ...

# %%
train_test_data.replace(['Capt','Col','Countess','Don','Dona','Dr','Jonkheer', 'Major','Mlle','Mme','Rev','Sir'], \
                        'Other' ,inplace =True)

train_test_data.replace(['Lady'],'Mrs' ,inplace =True)
train_test_data.replace(['Ms'],'Miss' ,inplace =True)

pd.crosstab( train_test_data['Title'], train_test_data['Sex'] , margins=True , margins_name = "Total" )
# Out:
# Sex     female  male  Total
# Title
# Master       0    61     61
# Miss       262     0    262
# Mr           0   757    757
# Mrs        198     0    198
# Other        6    25     31
# Total      466   843   1309

# %%
train_test_data[['Title', 'Survived']].groupby(['Title'], as_index=False).mean()
# Out:
#     Title  Survived
# 0  Master  0.575000
# 1    Miss  0.699454
# 2      Mr  0.156673
# 3     Mrs  0.793651
# 4   Other  0.400000

# %% [markdown]
# ### Title feature

# %% [markdown]
# Now the categorical data of Title will be converted to Numerical value
#
# - Mr     - 1
# - Miss   - 2
# - Mrs    - 3
# - Master - 4
# - Other  - 5

# %%
title_mapping = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Other": 5}

train_test_data['TitleNum'] = train_test_data['Title'].map(title_mapping )


train_test_data.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                   Name  Parch  PassengerId  \
# 0                              Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)      0            2
# 2                               Heikkinen, Miss. Laina      0            3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                             Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket Title  TitleNum
# 0       3    male      1       0.0         A/5 21171    Mr         1
# 1       1  female      1       1.0          PC 17599   Mrs         3
# 2       3  female      0       1.0  STON/O2. 3101282  Miss         2
# ...

# %%
train_test_data[['TitleNum', 'Survived']].groupby(['TitleNum'], as_index=False).mean()
# Out:
#    TitleNum  Survived
# 0         1  0.156673
# 1         2  0.699454
# 2         3  0.793651
# 3         4  0.575000
# 4         5  0.400000

# %%
train_test_data.isnull().sum()
# Out:
# Age             263
# Cabin          1014
# Embarked          2
# Fare              1
# Name              0
# Parch             0
# PassengerId       0
# Pclass            0
# Sex               0
# SibSp             0
# Survived        418
# Ticket            0
# Title             0
# TitleNum          0
# dtype: int64

# %% [markdown]
# ### Age feature

# %%
#To detect NaN values numpy uses np.isnan().
#To detect NaN values pandas uses either .isna() or .isnull().
    
import math

mean_age = train_test_data['Age'].mean()
std_age  = train_test_data['Age'].std()

age_null_count = train_test_data['Age'].isnull().sum()

print("Mean : ",mean_age)
print("Standard deviation : ", std_age)

print("Null count : ", age_null_count)

age_null_random_list = np.random.randint(mean_age - std_age , mean_age + std_age , size = age_null_count )

train_test_data['Age'][np.isnan(train_test_data['Age'])] = age_null_random_list

train_test_data['Age'] = train_test_data['Age'].astype(int)
# Out:
# Mean :  29.881137667304014
# Standard deviation :  14.413493211271334
# Null count :  263
# C:\Users\tshrs\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
train_test_data.isnull().sum()
# Out:
# Age               0
# Cabin          1014
# Embarked          2
# Fare              1
# Name              0
# Parch             0
# PassengerId       0
# Pclass            0
# Sex               0
# SibSp             0
# Survived        418
# Ticket            0
# Title             0
# TitleNum          0
# dtype: int64

# %%
train_test_data['Age band']=pd.cut(train_test_data['Age'],5)

train_test_data.head()
# Out:
#    Age Cabin Embarked     Fare  \
# 0   22   NaN        S   7.2500
# 1   38   C85        C  71.2833
# 2   26   NaN        S   7.9250
# 3   35  C123        S  53.1000
# 4   35   NaN        S   8.0500
#
#                                                   Name  Parch  PassengerId  \
# 0                              Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)      0            2
# 2                               Heikkinen, Miss. Laina      0            3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                             Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket Title  TitleNum  \
# 0       3    male      1       0.0         A/5 21171    Mr         1
# 1       1  female      1       1.0          PC 17599   Mrs         3
# 2       3  female      0       1.0  STON/O2. 3101282  Miss         2
# ...

# %%
train_test_data[['Age band', 'Survived']].groupby(['Age band'], as_index=False).mean()
# Out:
#         Age band  Survived
# 0  (-0.08, 16.0]  0.522936
# 1   (16.0, 32.0]  0.338565
# 2   (32.0, 48.0]  0.402344
# 3   (48.0, 64.0]  0.434783
# 4   (64.0, 80.0]  0.090909

# %%
### Create and empty column in dataset

train_test_data['AgeType'] = ""

# %%
train_test_data.head()
# Out:
#    Age Cabin Embarked     Fare  \
# 0   22   NaN        S   7.2500
# 1   38   C85        C  71.2833
# 2   26   NaN        S   7.9250
# 3   35  C123        S  53.1000
# 4   35   NaN        S   8.0500
#
#                                                   Name  Parch  PassengerId  \
# 0                              Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)      0            2
# 2                               Heikkinen, Miss. Laina      0            3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                             Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket Title  TitleNum  \
# 0       3    male      1       0.0         A/5 21171    Mr         1
# 1       1  female      1       1.0          PC 17599   Mrs         3
# 2       3  female      0       1.0  STON/O2. 3101282  Miss         2
# ...

# %%
train_test_data.loc[train_test_data['Age'] <= 16, 'AgeType' ] = 1
train_test_data.loc[(train_test_data['Age'] > 16) & (train_test_data['Age'] <= 32), 'AgeType' ] = 2
train_test_data.loc[(train_test_data['Age'] > 32) & (train_test_data['Age'] <= 48), 'AgeType' ] = 3
train_test_data.loc[(train_test_data['Age'] > 48) & (train_test_data['Age'] <= 64), 'AgeType' ] = 4
train_test_data.loc[(train_test_data['Age'] > 64) & (train_test_data['Age'] <= 80), 'AgeType' ] = 5

# %%
train_test_data.head()
# Out:
#    Age Cabin Embarked     Fare  \
# 0   22   NaN        S   7.2500
# 1   38   C85        C  71.2833
# 2   26   NaN        S   7.9250
# 3   35  C123        S  53.1000
# 4   35   NaN        S   8.0500
#
#                                                   Name  Parch  PassengerId  \
# 0                              Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)      0            2
# 2                               Heikkinen, Miss. Laina      0            3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                             Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket Title  TitleNum  \
# 0       3    male      1       0.0         A/5 21171    Mr         1
# 1       1  female      1       1.0          PC 17599   Mrs         3
# 2       3  female      0       1.0  STON/O2. 3101282  Miss         2
# ...

# %% [markdown]
# ### Sex feature

# %%
sex_mapping = {"male": 1, "female": 2, "Other": 5}

train_test_data['SexType'] = train_test_data['Sex'].map(sex_mapping )


train_test_data.head()
# Out:
#    Age Cabin Embarked     Fare  \
# 0   22   NaN        S   7.2500
# 1   38   C85        C  71.2833
# 2   26   NaN        S   7.9250
# 3   35  C123        S  53.1000
# 4   35   NaN        S   8.0500
#
#                                                   Name  Parch  PassengerId  \
# 0                              Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)      0            2
# 2                               Heikkinen, Miss. Laina      0            3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                             Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket Title  TitleNum  \
# 0       3    male      1       0.0         A/5 21171    Mr         1
# 1       1  female      1       1.0          PC 17599   Mrs         3
# 2       3  female      0       1.0  STON/O2. 3101282  Miss         2
# ...

# %%
train_test_data[['SexType', 'Survived']].groupby(['SexType'], as_index=False).mean()
# Out:
#    SexType  Survived
# 0        1  0.188908
# 1        2  0.742038

# %% [markdown]
# ### Embarked feature

# %%
train_test_data['Embarked'].value_counts()
# Out:
# S    914
# C    270
# Q    123
# Name: Embarked, dtype: int64

# %%
train_test_data['Embarked'].isnull().sum()
# Out:
# 2

# %% [markdown]
# **Note : Since there are only 2 empty values we will them as it is(we decided that before). BUT we got the below error when converting embarked type to some categorical numerical value. **
#
# *ValueError: Cannot convert non-finite values (NA or inf) to integer*
#
# So we decide to fill those null values as well.
#
# **PS** - Read the below article on why we are doing this feature conversion to numerical one.
#
# https://www.analyticsvidhya.com/blog/2015/11/easy-methods-deal-categorical-variables-predictive-modeling/

# %%
train_test_data.loc[train_test_data['Embarked'].isnull(), 'Embarked' ]
# Out:
# 61     NaN
# 829    NaN
# Name: Embarked, dtype: object

# %% [markdown]
# Since most records have Embarked = S, so marking the 2 column as 'S'

# %%
train_test_data.loc[train_test_data['Embarked'].isnull(), 'Embarked' ] = 'S'

# %%
train_test_data.loc[train_test_data['Embarked'].isnull(), 'Embarked' ]
# Out:
# Series([], Name: Embarked, dtype: object)

# %%
train_test_data['EmbarkedType'] = train_test_data['Embarked'].map({"S": 1, "C": 2, "Q": 3}).astype(int)

#train_test_data.drop('EmbarkedType',axis=1,inplace=True)

train_test_data.head()
# Out:
#    Age Cabin Embarked     Fare  \
# 0   22   NaN        S   7.2500
# 1   38   C85        C  71.2833
# 2   26   NaN        S   7.9250
# 3   35  C123        S  53.1000
# 4   35   NaN        S   8.0500
#
#                                                   Name  Parch  PassengerId  \
# 0                              Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)      0            2
# 2                               Heikkinen, Miss. Laina      0            3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                             Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket Title  TitleNum  \
# 0       3    male      1       0.0         A/5 21171    Mr         1
# 1       1  female      1       1.0          PC 17599   Mrs         3
# 2       3  female      0       1.0  STON/O2. 3101282  Miss         2
# ...

# %%
print(train_test_data['EmbarkedType'].value_counts())

print(train_test_data['Embarked'].value_counts())
# Out:
# 1    916
# 2    270
# 3    123
# Name: EmbarkedType, dtype: int64
# S    916
# C    270
# Q    123
# Name: Embarked, dtype: int64

# %% [markdown]
# ### Fare feature

# %%
train_test_data['Fare'].max()
# Out:
# 512.3292

# %%
train_test_data.loc[train_test_data['Fare'].idxmax()]
# Out:
# Age                           35
# Cabin                        NaN
# Embarked                       C
# Fare                     512.329
# Name            Ward, Miss. Anna
# Parch                          0
# PassengerId                  259
# Pclass                         1
# Sex                       female
# SibSp                          0
# Survived                       1
# Ticket                  PC 17755
# Title                       Miss
# TitleNum                       2
# Age band            (32.0, 48.0]
# AgeType                        3
# SexType                        2
# EmbarkedType                   2
# Name: 258, dtype: object

# %%
train_test_data['Fare'].min()
# Out:
# 0.0

# %%
train_test_data.loc[train_test_data['Fare'].idxmin()]
# Out:
# Age                              36
# Cabin                           NaN
# Embarked                          S
# Fare                              0
# Name            Leonard, Mr. Lionel
# Parch                             0
# PassengerId                     180
# Pclass                            3
# Sex                            male
# SibSp                             0
# Survived                          0
# Ticket                         LINE
# Title                            Mr
# TitleNum                          1
# Age band               (32.0, 48.0]
# AgeType                           3
# SexType                           1
# EmbarkedType                      1
# Name: 179, dtype: object

# %%
train_test_data['Fare'].isnull().sum()
# Out:
# 1

# %% [markdown]
# Fill the missing value with median

# %%
train_test_data['Fare'].fillna(train_test_data['Fare'].median(), inplace=True)

train_test_data['Fare'].isnull().sum()
# Out:
# 0

# %%
#qcut,the bins will be chosen so that you have the same number of records in each bin. You have 30 records
#so should have 6 in each bin

## Diff be cut and qcut - 
## https://stackoverflow.com/questions/30211923/what-is-the-difference-between-pandas-qcut-and-pandas-cut

train_test_data['FareBand']=pd.qcut(train_test_data['Fare'],4)

#train_test_data.drop('FareBand',axis=1,inplace=True)

train_test_data.head()
# Out:
#    Age Cabin Embarked     Fare  \
# 0   22   NaN        S   7.2500
# 1   38   C85        C  71.2833
# 2   26   NaN        S   7.9250
# 3   35  C123        S  53.1000
# 4   35   NaN        S   8.0500
#
#                                                   Name  Parch  PassengerId  \
# 0                              Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)      0            2
# 2                               Heikkinen, Miss. Laina      0            3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                             Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket Title  TitleNum  \
# 0       3    male      1       0.0         A/5 21171    Mr         1
# 1       1  female      1       1.0          PC 17599   Mrs         3
# 2       3  female      0       1.0  STON/O2. 3101282  Miss         2
# ...

# %%
train_test_data['FareBand'].value_counts()
# Out:
# (-0.001, 7.896]      337
# (14.454, 31.275]     328
# (31.275, 512.329]    323
# (7.896, 14.454]      321
# Name: FareBand, dtype: int64

# %% [markdown]
# Now let's map these bands to fare types such as 1,2,3,4.

# %%
#creating a new empty feature

train_test_data['FareType'] = ""

train_test_data.head()
# Out:
#    Age Cabin Embarked     Fare  \
# 0   22   NaN        S   7.2500
# 1   38   C85        C  71.2833
# 2   26   NaN        S   7.9250
# 3   35  C123        S  53.1000
# 4   35   NaN        S   8.0500
#
#                                                   Name  Parch  PassengerId  \
# 0                              Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)      0            2
# 2                               Heikkinen, Miss. Laina      0            3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                             Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket Title  TitleNum  \
# 0       3    male      1       0.0         A/5 21171    Mr         1
# 1       1  female      1       1.0          PC 17599   Mrs         3
# 2       3  female      0       1.0  STON/O2. 3101282  Miss         2
# ...

# %%
train_test_data.loc[train_test_data['Fare'] <= 7.896, 'FareType' ] = 1
train_test_data.loc[(train_test_data['Fare'] > 7.896) & (train_test_data['Fare'] <= 14.454), 'FareType' ] = 2
train_test_data.loc[(train_test_data['Fare'] > 14.454) & (train_test_data['Fare'] <=  31.275), 'FareType' ] = 3
train_test_data.loc[(train_test_data['Fare'] >  31.275) & (train_test_data['Fare'] <= 512.5), 'FareType' ] = 4


train_test_data.head()
# Out:
#    Age Cabin Embarked     Fare  \
# 0   22   NaN        S   7.2500
# 1   38   C85        C  71.2833
# 2   26   NaN        S   7.9250
# 3   35  C123        S  53.1000
# 4   35   NaN        S   8.0500
#
#                                                   Name  Parch  PassengerId  \
# 0                              Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)      0            2
# 2                               Heikkinen, Miss. Laina      0            3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                             Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket Title  TitleNum  \
# 0       3    male      1       0.0         A/5 21171    Mr         1
# 1       1  female      1       1.0          PC 17599   Mrs         3
# 2       3  female      0       1.0  STON/O2. 3101282  Miss         2
# ...

# %%
train_test_data['FareType'].value_counts()
# Out:
# 3    339
# 1    337
# 4    323
# 2    310
# Name: FareType, dtype: int64

# %%
train_test_data[['FareType', 'Survived']].groupby(['FareType'], as_index=False).count()
# Out:
#    FareType  Survived
# 0         1       223
# 1         2       217
# 2         3       236
# 3         4       215

# %% [markdown]
# ### SibSp & Parch feature

# %%
print(train_test_data['SibSp'].isnull().sum())
print(train_test_data['Parch'].isnull().sum())
# Out:
# 0
# 0

# %%
train_test_data['FamilySize'] = train_test_data['SibSp'] + train_test_data['Parch'] + 1
# +1 if for the person itself

train_test_data.head()
# Out:
#    Age Cabin Embarked     Fare  \
# 0   22   NaN        S   7.2500
# 1   38   C85        C  71.2833
# 2   26   NaN        S   7.9250
# 3   35  C123        S  53.1000
# 4   35   NaN        S   8.0500
#
#                                                   Name  Parch  PassengerId  \
# 0                              Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)      0            2
# 2                               Heikkinen, Miss. Laina      0            3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                             Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket Title  TitleNum  \
# 0       3    male      1       0.0         A/5 21171    Mr         1
# 1       1  female      1       1.0          PC 17599   Mrs         3
# 2       3  female      0       1.0  STON/O2. 3101282  Miss         2
# ...

# %%
train_test_data['FamilySize'].value_counts()
# Out:
# 1     790
# 2     235
# 3     159
# 4      43
# 6      25
# 5      22
# 7      16
# 11     11
# 8       8
# Name: FamilySize, dtype: int64

# %%
train_test_data[['FamilySize','Survived']].groupby(['FamilySize'], as_index=False).mean()
# Out:
#    FamilySize  Survived
# 0           1  0.303538
# 1           2  0.552795
# 2           3  0.578431
# 3           4  0.724138
# 4           5  0.200000
# 5           6  0.136364
# 6           7  0.333333
# 7           8  0.000000
# 8          11  0.000000

# %% [markdown]
# - Having family size upto 2-4 have better chance of survival.
# - Persons visiting alone i.e. size=1 have lesser chance.
# - Also for bigger families chance is less.

# %% [markdown]
# *Let's create a new feature IsAlone and mark those as 1 whoever are alone.*

# %%
train_test_data['IsAlone'] = 0
train_test_data.loc[train_test_data['FamilySize'] == 1, 'IsAlone' ] = 1

# %%
train_test_data['IsAlone'].value_counts()
# Out:
# 1    790
# 0    519
# Name: IsAlone, dtype: int64

# %%
train_test_data[['IsAlone','Survived']].groupby(['IsAlone'], as_index=False).mean()
# Out:
#    IsAlone  Survived
# 0        0  0.505650
# 1        1  0.303538

# %% [markdown]
# *Alone people have around 30% chance of survival*

# %%
list(train_test_data)
# Out:
# ['Age',
#  'Cabin',
#  'Embarked',
#  'Fare',
#  'Name',
#  'Parch',
#  'PassengerId',
#  'Pclass',
#  'Sex',
#  'SibSp',
#  'Survived',
#  'Ticket',
#  'Title',
#  'TitleNum',
#  'Age band',
#  'AgeType',
#  'SexType',
#  'EmbarkedType',
#  'FareBand',
#  'FareType',
#  'FamilySize',
#  'IsAlone']

# %%
list(train_data)
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
list(test_data)
# Out:
# ['PassengerId',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %% [markdown]
# ***Since the train and test data are merged into single dataframe i.e. train_test_data with all the new columns in feature extraction process, we need to split this into train and test data again based on:***
# - Survived values filled = train data
# - Survived values NaN = test data

# %%
train_test_data['Survived'].isnull().sum()
# Out:
# 418

# %% [markdown]
# ### New train data set

# %%
train = train_test_data.loc[train_test_data['Survived'].notnull()]

# %%
train['Survived'] = train['Survived'].astype(int)
# Out:
# C:\Users\tshrs\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
train.head()
# Out:
#    Age Cabin Embarked     Fare  \
# 0   22   NaN        S   7.2500
# 1   38   C85        C  71.2833
# 2   26   NaN        S   7.9250
# 3   35  C123        S  53.1000
# 4   35   NaN        S   8.0500
#
#                                                   Name  Parch  PassengerId  \
# 0                              Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)      0            2
# 2                               Heikkinen, Miss. Laina      0            3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                             Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket Title  TitleNum  \
# 0       3    male      1         0         A/5 21171    Mr         1
# 1       1  female      1         1          PC 17599   Mrs         3
# 2       3  female      0         1  STON/O2. 3101282  Miss         2
# ...

# %% [markdown]
# ### New test data

# %%
test = train_test_data.loc[train_test_data['Survived'].isnull()]

# %%
test.head()
# Out:
#      Age Cabin Embarked     Fare  \
# 891   34   NaN        Q   7.8292
# 892   47   NaN        S   7.0000
# 893   62   NaN        Q   9.6875
# 894   27   NaN        S   8.6625
# 895   22   NaN        S  12.2875
#
#                                              Name  Parch  PassengerId  Pclass  \
# 891                              Kelly, Mr. James      0          892       3
# 892              Wilkes, Mrs. James (Ellen Needs)      0          893       3
# 893                     Myles, Mr. Thomas Francis      0          894       2
# 894                              Wirz, Mr. Albert      0          895       3
# 895  Hirvonen, Mrs. Alexander (Helga E Lindqvist)      1          896       3
#
#         Sex  SibSp  Survived   Ticket Title  TitleNum      Age band  AgeType  \
# 891    male      0       NaN   330911    Mr         1  (32.0, 48.0]        3
# 892  female      1       NaN   363272   Mrs         3  (32.0, 48.0]        3
# ...

# %% [markdown]
# # 3- Feature Selection
# -------------------------------------

# %%
features_drop = ['Name', 'SibSp' , 'Cabin' , 'Ticket', 'Parch','Title','Age band','FareBand','Embarked','Sex']
train = train.drop(features_drop, axis=1)
test  =  test.drop(features_drop, axis=1)
train = train.drop(['PassengerId'], axis=1)

# %%
train.head()
# Out:
#    Age     Fare  Pclass  Survived  TitleNum  AgeType  SexType  EmbarkedType  \
# 0   22   7.2500       3         0         1        2        1             1
# 1   38  71.2833       1         1         3        3        2             2
# 2   26   7.9250       3         1         2        2        2             1
# 3   35  53.1000       1         1         3        3        2             1
# 4   35   8.0500       3         0         1        3        1             1
#
#    FareType  FamilySize  IsAlone
# 0         1           2        0
# 1         4           2        0
# 2         2           1        1
# 3         4           2        0
# 4         2           1        1

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 11 columns):
# Age             891 non-null int32
# Fare            891 non-null float64
# Pclass          891 non-null int64
# Survived        891 non-null int32
# TitleNum        891 non-null int64
# AgeType         891 non-null int64
# SexType         891 non-null int64
# EmbarkedType    891 non-null int32
# FareType        891 non-null int64
# FamilySize      891 non-null int64
# IsAlone         891 non-null int64
# dtypes: float64(1), int32(3), int64(7)
# memory usage: 73.1 KB

# %%
test.head()
# Out:
#      Age     Fare  PassengerId  Pclass  Survived  TitleNum  AgeType  SexType  \
# 891   34   7.8292          892       3       NaN         1        3        1
# 892   47   7.0000          893       3       NaN         3        3        2
# 893   62   9.6875          894       2       NaN         1        4        1
# 894   27   8.6625          895       3       NaN         1        2        1
# 895   22  12.2875          896       3       NaN         3        2        2
#
#      EmbarkedType  FareType  FamilySize  IsAlone
# 891             3         1           1        1
# 892             1         1           2        0
# 893             3         2           1        1
# 894             1         2           1        1
# 895             1         2           3        0

# %% [markdown]
# ## 4- Classification and Accuracy
# ------------------------------------------------

# %% [markdown]
# Let's define training and testing data set with labels and target.

# %%
X_train = train.drop(['Survived','Fare','Age'], axis=1)
y_train = train['Survived']

X_test = test.drop(['Survived','PassengerId','Fare','Age'], axis=1)

X_train.shape, y_train.shape, X_test.shape
# Out:
# ((891, 8), (891,), (418, 8))

# %% [markdown]
# There are many classification alogorithms. We try some of the below:
# - Logistic Regression
# - SVM(SVC classifier)
# - Naive Bayes
# - k-nearest neighbor(kNN)
# - Decision tree
# - Random Forest
#
#
# Here's the training and testing procedure:
# - We first train the classifiers/model with training data set
# - Using trained model, we predict the Survival of our test data set.
# - Finally, we calculate accuracy.

# %%
# Importing Classifier Modules
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier

# %% [markdown]
# ### Logistic regression
#
# We will be using - Binomial (used in this eg), as there are 2 target variables
#
# https://developers.google.com/machine-learning/crash-course/logistic-regression/video-lecture

# %%
X_train.head()
# Out:
#    Pclass  TitleNum  AgeType  SexType  EmbarkedType  FareType  FamilySize  \
# 0       3         1        2        1             1         1           2
# 1       1         3        3        2             2         4           2
# 2       3         2        2        2             1         2           1
# 3       1         3        3        2             1         4           2
# 4       3         1        3        1             1         2           1
#
#    IsAlone
# 0        0
# 1        0
# 2        1
# 3        0
# 4        1

# %%
X_test.head()
# Out:
#      Pclass  TitleNum  AgeType  SexType  EmbarkedType  FareType  FamilySize  \
# 891       3         1        3        1             3         1           1
# 892       3         3        3        2             1         1           2
# 893       2         1        4        1             3         2           1
# 894       3         1        2        1             1         2           1
# 895       3         3        2        2             1         2           3
#
#      IsAlone
# 891        1
# 892        0
# 893        1
# 894        1
# 895        0

# %%
clf = LogisticRegression()
clf.fit(X_train, y_train)
y_pred_log_reg = clf.predict(X_test)
acc_log_reg = round( clf.score(X_train, y_train) * 100, 2)
print (str(acc_log_reg) + ' percent')
# Out:
# 81.14 percent

# %% [markdown]
# ***Note : Here we are not using accuracy_score(labels_test, prediction) -- because we are just classifying based on training data set. We are not splitting the data set into training and testing data set.***
#
# ***We have a seperate testing data set which will be used later***

# %% [markdown]
# The above function fit and predict were giving error  *ValueError: could not convert string to float:*
# So, we went back and removed the columns Age and found that AgeType had some empty values(spaces), so corrected that and AgeType has no empty spaces value now.

# %% [markdown]
# ### Support Vector Machines(SVM)
#
# Naive bayes will make a somewhat curvy line but S/vm will always make a straght line/hyperplane. But we also see that t gives non-linear decision boundry, how on earth possible? Ans- Add a new feature, also called a Kernel trick. What it does is creates new high dimensional function of existing features like x,y -> kernel -> x^2 + y^2 -> non-linear seperable line(solution). There are differet types of kernels.
#
# 1. Both classification(mostly) and regression problems
# 2. Finding a hyperplane(line) that best divides datasets into 2 classes
# 3. Support vectors are data points nearest to hyperplane
# 4. Further the data points from the hyperplane -- better the classification
# 5. Distance bw hyperplane and data points are called -- margin, we choose the greatest poosible margin
# 6. In 2d, it will be line BUT when it's a 3d it has to be hyperplane(imagine balls in air)
# 7. *Pros* : accuracy, smaller data works best , *Cons* : Larger data, noiser datasets less affective
# 8. Color base classification
# 9. We use a SVC classifier
# 10. There is a gamma parameter used with kernel in SVC function, defines how far influence of single training exampl reaches -> low value - far reach - eg. a decision boundry line which separates will consider points which are even far away. low value may  cause overfit
# 11. The parameter C - controls tradeoff bw smooth decision boundry and classifying training points correctly. Large C -> more training poits correctly - may give overfitting
# 12. Which of these are applications where you can imagine a very quick-running algorithm is especially important?
#     predicting the author of an email.
#     - flagging credit card fraud, and blocking a transaction before it goes through.
#     - voice recognition, like Siri

# %%
clf = SVC()
clf.fit(X_train, y_train)
y_pred_svc = clf.predict(X_test)
acc_svc = round(clf.score(X_train, y_train) * 100, 2)
print (acc_svc)
# Out:
# 83.5

# %% [markdown]
# ### Gaussian Naive Bayes
#
# https://www.analyticsvidhya.com/blog/2017/09/naive-bayes-explained/

# %%
clf = GaussianNB()
clf.fit(X_train, y_train)
y_pred_gnb = clf.predict(X_test)
acc_gnb = round(clf.score(X_train, y_train) * 100, 2)
print (acc_gnb)
# Out:
# 79.91

# %% [markdown]
# ### K-nearest neigbour(knn)
#
# 1. k-nearest - classic, simple, easy to understand
# 2. classification algorithm which can be used in regression problems as well (but not recommended)
# 3. It goes through the complete training data every time it needs to predict a test sample’s classification label! This is why it’s called a Lazy learning technique.
# 4. classification is driven by Euclidean distances. This distance is measured by a formula  which takes distance bw all the points in data set and the target point. As per the value if k, nearest distance value points are choosen.
# 5. kNN classifier doesn’t perform very well on imbalanced data
# 6. Below are good explanations:
#   - https://www.youtube.com/watch?v=UqYde-LULfs&t=4s
#   - https://www.youtube.com/watch?v=4HKqjENq9OU&t=581s
# 7. how to choose k? choose square root(n), n is total data points(features) odd value of k is choosen
# 8. Used when data is clean and small

# %%
clf = KNeighborsClassifier(n_neighbors = 3)
clf.fit(X_train, y_train)
y_pred_knn = clf.predict(X_test)
acc_knn = round(clf.score(X_train, y_train) * 100, 2)
print (acc_knn)
# Out:
# 85.97

# %% [markdown]
# ### Decision tree
#
# 1. Helps you find multiple questions and then answers it.
# 2. Uses a tree like structure asking yes & no questions
# 3. Uses as classifier, also can be used for regression.
# 4. Parameter min_sample_split -> in each node of a tree it can be split min as many times as the value, eg. value=2, is node has 1 sample, it cannot be split further. Lower the value more complex and overfitting is the decision boundry.
# 5. Entropy -> controls how a DT decides to split the data. Makes data as pure as possible, means same class data in one classification(min_sample_split). All examples same class -> entropy = 0 , examples are evenly split -> entropy =1(max value) , this is the most evenly split bw 2 class lables.
# 6. Information gain helps to decide split the data by use of entropy. DT algo will try to maximize info gain. Suppose the info gain is zero, we will not choose that feature to split our decision tree.See screenshot example
# 7. Criterion paramter has "gini" as well as "entropy"
# 8. Bias- Variance dilemma. High bias ML algo ignores the data, no capacity of learning. High Variance ML algo can only replicate data that it has seen before, bad when has to react to new stuff. Adjustment of these 2 make ML algo best

# %%
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
y_pred_decision_tree = clf.predict(X_test)
acc_decision_tree = round(clf.score(X_train, y_train) * 100, 2)
print (acc_decision_tree)
# Out:
# 89.45

# %% [markdown]
# ### Random Forest
#
# https://www.youtube.com/watch?v=QHOazyP-YlM
# https://www.youtube.com/watch?v=eM4uJ6XGnSM&t=1s
# https://github.com/llSourcell/random_forests
#
# It is a collection of decision tree. Used more often
# Decision tree gets overfit
# (binary tree, that is either left node or right node)
#
#  1- Set of decision to verify some decision.
#  2- USed for both classification and regression , CART.
#  3- tree is build recursively.
#  4- how to build optimal tree, which says temp>70 or wind>2mph to make a  decision yes or no, where are these numbers coming from? That's what we find.
#  5- They come from Gini index (cost function) , Gini(t) , so we are not trying to find minimize any error or find optimal value, we are here trying to find cost.
# 6- For every single point we have bunch of features, we want to find that idle value for that feature.
# i.e.
# we have 10 features
# income - 1k bw 1million
#
# iterate thru every data point and compute thru Gini index = (1- avg) * avg
# it gives index for each data points.
# 7-Idle Gini score is 1
# 8-How we build
#   a- we construct the tree
#   b- we prune the tree(irrelevant forrest - identify outliers and remove it)
# 9- Bunch of trees(sample of diff datasets)
# 10-This is exhaustive and greedy algo

# %%
clf = RandomForestClassifier(n_estimators=100)
clf.fit(X_train, y_train)
y_pred_random_forest = clf.predict(X_test)
acc_random_forest = round(clf.score(X_train, y_train) * 100, 2)
print (acc_random_forest)
# Out:
# 89.45

# %% [markdown]
# ### Evaluation Metrics
#
# 1- Accuracy = no. of items labeled correctly / all items
#
# 2- Accuracy not ideal in blow case:
# 	i- skewed class - large data in one class and few in other class
# 	ii- if you want to guess on the error side -- this proof is not enough
#
# 3- Confusion matrix - 2d matrix	 - this is as per python sklearn
#
#
# | Actual / Predicted 	| No 	| Yes 	|
# |--------------------	|----	|-----	|
# | No                 	| TN 	| FP  	|
# | Yes                	| FN 	| TP  	|
#
# Thus in binary classification, the count of true negatives is c00 , false negatives is c10 , true positives c11 is  and false positives is c01.
#
#
# 4- Recall and precison
# Recall = probability of actual i.e. true point/all point
# Precision = probability of predicted i.e. predicted point/all point
#
# Or
#
# Recall: True Positive / (True Positive + False Negative). Out of all the items that are truly positive, how many were correctly classified as positive. Or simply, how many positive items were 'recalled' from the dataset.
#
# Precision: True Positive / (True Positive + False Positive). Out of all the items labeled as positive, how many truly belong to the positive class.
#
# https://classroom.udacity.com/courses/ud120/lessons/2945338635/concepts/30294985830923
#
# 5- True positive,false +ve, false -ve example
# https://classroom.udacity.com/courses/ud120/lessons/2945338635/concepts/30294985960923
#
# 6- F1 score - measure of test accuracy
# https://en.wikipedia.org/wiki/F1_score
# F1 = 2 * (precision * recall) / (precision + recall)

# %% [markdown]
# ### Confusion Matrix
#
# https://www.dataschool.io/simple-guide-to-confusion-matrix-terminology/
#
# In predictive analytics, a table of confusion (sometimes also called a confusion matrix), is a table with two rows and two columns that reports the number of false positives, false negatives, true positives, and true negatives. This allows more detailed analysis than mere proportion of correct classifications (accuracy). Accuracy is not a reliable metric for the real performance of a classifier, because it will yield misleading results if the data set is unbalanced (that is, when the numbers of observations in different classes vary greatly). For example, if there were 95 cats and only 5 dogs in the data set, a particular classifier might classify all the observations as cats. The overall accuracy would be 95%, but in more detail the classifier would have a 100% recognition rate for the cat class but a 0% recognition rate for the dog class.
#
#
# >**True Positive:** The classifier predicted *Survived* **and** the passenger actually *Survived*.
# >
# >**True Negative:** The classifier predicted *Not Survived* **and** the passenger actually *Not Survived*.
# >
# >**False Postiive:** The classifier predicted *Survived* **but** the passenger actually *Not Survived*.
# >
# >**False Negative:** The classifier predicted *Not Survived* **but** the passenger actually *Survived*.

# %% [markdown]
# We will calculate Evaluation metrics for ***Random Forest*** classifier.

# %%
#confusion matrix for training data set

from sklearn.metrics import confusion_matrix

clf = RandomForestClassifier(n_estimators=100)
clf.fit(X_train, y_train)
y_pred_random_forest_training_set = clf.predict(X_train)
acc_random_forest = round(clf.score(X_train, y_train) * 100, 2)
print ("Accuracy: %i %%\n"%acc_random_forest)

class_names = ['Survived', 'Not Survived']

cnf_matrix = confusion_matrix(y_train, y_pred_random_forest_training_set)

print ('Confusion Matrix in Numbers')
print (cnf_matrix)
print ('')

cnf_matrix_percent = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]
print ('Confusion Matrix in Percentage')
print (cnf_matrix_percent)
print ('')


true_class_names = ['True Survived', 'True Not Survived']
predicted_class_names = ['Predicted Survived', 'Predicted Not Survived']

df_cnf_matrix = pd.DataFrame(cnf_matrix, 
                             index = true_class_names,
                             columns = predicted_class_names)

df_cnf_matrix_percent = pd.DataFrame(cnf_matrix_percent, 
                                     index = true_class_names,
                                     columns = predicted_class_names)

plt.figure(figsize = (15,5))

plt.subplot(121)
sns.heatmap(df_cnf_matrix, annot=True, fmt='d')

plt.subplot(122)
sns.heatmap(df_cnf_matrix_percent, annot=True)
# Out:
# Accuracy: 89 %
#
# Confusion Matrix in Numbers
# [[516  33]
#  [ 61 281]]
#
# Confusion Matrix in Percentage
# [[0.94 0.06]
#  [0.18 0.82]]

# %% [markdown]
# ### Comparing models

# %%
#Logistic Regression
#SVM(SVC classifier)
#Naive Bayes
#k-nearest neighbor(kNN)
#Decision tree
#Random Forest

models = pd.DataFrame({
    'Model': ['Logistic Regression', 'Support Vector Machines', 'Naive Bayes', 
              'KNN', 'Decision Tree', 'Random Forest'],
    
    'Score': [acc_log_reg, acc_svc, acc_gnb,  
              acc_knn,  acc_decision_tree, acc_random_forest]
    })


models.sort_values(by='Score', ascending=False)
# Out:
#                      Model  Score
# 4            Decision Tree  89.45
# 5            Random Forest  89.45
# 3                      KNN  85.97
# 1  Support Vector Machines  83.50
# 0      Logistic Regression  81.14
# 2              Naive Bayes  79.91

# %% [markdown]
# *We can see that Decision Tree and Random Forest has highest score, but we use Random Forest because Decision trees may cause Overfiting of data.*

# %%
test.head()
# Out:
#      Age     Fare  PassengerId  Pclass  Survived  TitleNum  AgeType  SexType  \
# 891   34   7.8292          892       3       NaN         1        3        1
# 892   47   7.0000          893       3       NaN         3        3        2
# 893   62   9.6875          894       2       NaN         1        4        1
# 894   27   8.6625          895       3       NaN         1        2        1
# 895   22  12.2875          896       3       NaN         3        2        2
#
#      EmbarkedType  FareType  FamilySize  IsAlone
# 891             3         1           1        1
# 892             1         1           2        0
# 893             3         2           1        1
# 894             1         2           1        1
# 895             1         2           3        0

# %% [markdown]
# ## Submission

# %%
submission = pd.DataFrame({
        "PassengerId": test["PassengerId"],
        "Survived": y_pred_random_forest
    })

#submission.to_csv('submission.csv', index=False)
